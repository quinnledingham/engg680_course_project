# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle

import torch
import torch.nn as nn
from torch.nn import functional as F

from input import Input_Data

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from stt import main
transformer_model, transformer_losses = main()
# Calls the main function from 'stt' module to train the transformer model,
# and retrieve training/validation losses.

torch.save(transformer_model.state_dict(), "./models/five_years.model")
# Saves the trained transformer model weights to a file for future use.
# Out:
# 10.806529 M parameters
# step 0: train loss 0.24131294, val loss 0.23992151, time 396.4212255477905
# step 500: train loss 0.00003373, val loss 0.00001246, time 467.16899251937866
# step 1000: train loss 0.00004957, val loss 0.00001297, time 536.3748540878296
# step 1500: train loss 0.00002958, val loss 0.00001074, time 603.8583176136017
# step 2000: train loss 0.00002987, val loss 0.00001154, time 671.371741771698
# step 2500: train loss 0.00003302, val loss 0.00001341, time 741.3825268745422
# step 3000: train loss 0.00003026, val loss 0.00001237, time 806.3316004276276
# step 3500: train loss 0.00002601, val loss 0.00001452, time 873.3863954544067
# step 4000: train loss 0.00005270, val loss 0.00001293, time 935.5782146453857
# step 4500: train loss 0.00002663, val loss 0.00001087, time 996.9878733158112
# step 4999: train loss 0.00004876, val loss 0.00001857, time 1059.6120088100433

# %%
from linear import main_linear
linear_model, linear_losses = main_linear()
# Calls the main_linear function to train a simpler linear model and retrieve losses.

torch.save(linear_model.state_dict(), "./models/five_years_linear.model")
# Out:
# step 0: train loss 0.00017276, val loss 0.00005854, time 10.79427194595337
# step 500: train loss 0.00001112, val loss 0.00000790, time 30.738510131835938
# step 1000: train loss 0.00000400, val loss 0.00000186, time 50.733412981033325
# step 1500: train loss 0.00000121, val loss 0.00000095, time 71.11148810386658
# step 2000: train loss 0.00000205, val loss 0.00000102, time 91.29714012145996
# step 2500: train loss 0.00000103, val loss 0.00000069, time 111.27917075157166
# step 3000: train loss 0.00000080, val loss 0.00000058, time 131.2806167602539
# step 3500: train loss 0.00000168, val loss 0.00000098, time 151.3991358280182
# step 4000: train loss 0.00005979, val loss 0.00001071, time 171.3442521095276
# step 4500: train loss 0.00000065, val loss 0.00000057, time 192.12813258171082
# step 4999: train loss 0.00000036, val loss 0.00000027, time 212.2456796169281

# %%
with open("./models/transformer_losses.loss", "wb") as fp:
    pickle.dump(transformer_losses, fp)

with open("./models/linear_losses.loss", "wb") as fp:
    pickle.dump(linear_losses, fp)
